# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn
# %matplotlib inline

# %%
def read_data(path):
    df = pd.read_csv(path, infer_datetime_format=True, dtype=str)
    df.columns = df.columns.str.strip()
    df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
    numeric_cols = ['CPRECIO', 'COSTOPESOS', '#UNIDADES', 'CTIPOCAM01']
    for col in numeric_cols:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce') 
    cols = df.columns.values
    cols[-4] = "YEAR"
    df.columns = cols
    return df

def read_test_data(path):
    df = pd.read_csv(path, infer_datetime_format=True,dtype=str)
    df.columns = df.columns.str.strip()
    df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
    numeric_cols = ['CPRECIO', 'COSTOPESOS', '#UNIDADES', 'CTIPOCAM01']
    for col in numeric_cols:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')
    cols = df.columns.values
    cols[-4] = "YEAR"
    df.columns = cols

    return df

def calculate_extra_cols(df):
    df['total_price'] =  df['CPRECIO'] * df['#UNIDADES'] * df['CTIPOCAM01']
    return df

# %%
df = read_data('/kaggle/input/series-data/BASEVENTAS2010A2015.csv')
df = calculate_extra_cols(df)
# Out:
# <ipython-input-103-d89bd9cdfcd3>:2: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df = pd.read_csv(path, infer_datetime_format=True, dtype=str)
# <ipython-input-103-d89bd9cdfcd3>:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %% [markdown]
# ### Lets start with the brands

# %%
df["MARCA"] = df["MARCA"].fillna("").astype(str).map(lambda x: x.strip())
df["IDPRODUCTO"] = df["IDPRODUCTO"].map(lambda x: x.strip())
df.head()
# Out:
#   FOLIO_FACTURA IDPRODUCTO                                MARCA  #UNIDADES  \
# 0        489434      85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS         12
# 1        489434     79323P                   PINK CHERRY LIGHTS         12
# 2        489434     79323W                  WHITE CHERRY LIGHTS         12
# 3        489434      22041          RECORD FRAME 7" SINGLE SIZE         48
# 4        489434      21232       STRAWBERRY CERAMIC TRINKET BOX         24
#
#                  FECHA  CPRECIO IDCLIENTE  YEAR  CTIPOCAM01 MES  COSTOPESOS  \
# 0  2009-12-01 07:45:00     6.95   13085.0  2009   19.498160  12   74.421469
# 1  2009-12-01 07:45:00     6.75   13085.0  2009   21.802857  12   93.309442
# 2  2009-12-01 07:45:00     6.75   13085.0  2009   20.927976  12   69.582270
# 3  2009-12-01 07:45:00     2.10   13085.0  2009   20.394634  12   90.265710
# 4  2009-12-01 07:45:00     1.25   13085.0  2009   18.624075  12   34.079459
#
#    total_price
# 0  1626.146584
# 1  1766.031435
# 2  1695.166037
# 3  2055.779101
# 4   558.722237

# %%
# 5 most important Brands by quantity across 5 years
df['IDPRODUCTO'] = df['IDPRODUCTO'].str.extract('(\d+)')
top5 = df.groupby("MARCA")["#UNIDADES"].sum().sort_values(ascending=False)[:5]
top5
df.head()
# Out:
#   FOLIO_FACTURA IDPRODUCTO                                MARCA  #UNIDADES  \
# 0        489434      85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS         12
# 1        489434      79323                   PINK CHERRY LIGHTS         12
# 2        489434      79323                  WHITE CHERRY LIGHTS         12
# 3        489434      22041          RECORD FRAME 7" SINGLE SIZE         48
# 4        489434      21232       STRAWBERRY CERAMIC TRINKET BOX         24
#
#                  FECHA  CPRECIO IDCLIENTE  YEAR  CTIPOCAM01 MES  COSTOPESOS  \
# 0  2009-12-01 07:45:00     6.95   13085.0  2009   19.498160  12   74.421469
# 1  2009-12-01 07:45:00     6.75   13085.0  2009   21.802857  12   93.309442
# 2  2009-12-01 07:45:00     6.75   13085.0  2009   20.927976  12   69.582270
# 3  2009-12-01 07:45:00     2.10   13085.0  2009   20.394634  12   90.265710
# 4  2009-12-01 07:45:00     1.25   13085.0  2009   18.624075  12   34.079459
#
#    total_price
# 0  1626.146584
# 1  1766.031435
# 2  1695.166037
# 3  2055.779101
# 4   558.722237

# %% [markdown]
# #### Lets check the volume of the top brands

# %%
df["FECHA"] = pd.to_datetime(df["FECHA"], errors="coerce")
df = df.dropna(subset=["FECHA"]).set_index("FECHA")  
df = df.sort_index()
ts = df[["#UNIDADES", "MARCA", "total_price"]]
units_ts = ts[["#UNIDADES", "MARCA"]]

plt.figure(figsize=(12, 8))

for brand in top5.index:
    new_ts = units_ts[units_ts["MARCA"] == brand]["#UNIDADES"]
    if not new_ts.loc["2009-12":].empty:
        new_ts = new_ts.loc["2009-12":].resample("3W").sum()
        new_ts.plot(ax=plt.gca(), label=brand)

plt.legend()
plt.title("Volume per Top Brands")
plt.show()

# %% [markdown]
# #### Top 5 brands by price

# %%
# 5 most important Brands by revenue across 5 years
top_b_p = df.groupby("MARCA")["total_price"].sum().sort_values(ascending=False)[:5]
top_b_p
# Out:
# MARCA
# REGENCY CAKESTAND 3 TIER              6.565473e+06
# DOTCOM POSTAGE                        6.426610e+06
# WHITE HANGING HEART T-LIGHT HOLDER    5.142518e+06
# JUMBO BAG RED RETROSPOT               2.980612e+06
# PARTY BUNTING                         2.951781e+06
# Name: total_price, dtype: float64

# %%
revenue_ts = ts[["total_price", "MARCA"]]
for brand in top_b_p.index[:5]:
    new_ts = revenue_ts[units_ts["MARCA"] == brand]["total_price"]
    if not new_ts.loc["2009-12":].empty:
        new_ts = new_ts.loc["2009-12":].resample("10W").sum()
        new_ts.plot(ax=plt.gca(), label=brand,figsize=(12, 5))
    # new_ts = new_ts["2013":].resample("10W").sum()
    # new_ts.plot(ax=plt.gca(), label=brand, figsize=(12, 5))
plt.legend()
df.tail()
# brandts.plot(logy=True)
# Out:
#                     FOLIO_FACTURA IDPRODUCTO                          MARCA  \
# FECHA
# 2011-12-09 12:50:00        581587      22555      PLASTERS IN TIN STRONGMAN
# 2011-12-09 12:50:00        581587      22556  PLASTERS IN TIN CIRCUS PARADE
# 2011-12-09 12:50:00        581587      22138   BAKING SET 9 PIECE RETROSPOT
# 2011-12-09 12:50:00        581587      22730     ALARM CLOCK BAKELIKE IVORY
# 2011-12-09 12:50:00        581587        NaN                        POSTAGE
#
#                      #UNIDADES  CPRECIO IDCLIENTE  YEAR  CTIPOCAM01 MES  \
# FECHA
# 2011-12-09 12:50:00         12     1.65   12680.0  2011   20.261492  12
# 2011-12-09 12:50:00         12     1.65   12680.0  2011   21.760984  12
# 2011-12-09 12:50:00          3     4.95   12680.0  2011   20.965274  12
# 2011-12-09 12:50:00          4     3.75   12680.0  2011   20.313163  12
# 2011-12-09 12:50:00          1    18.00   12680.0  2011   21.644754  12
#
#                      COSTOPESOS  total_price
# FECHA
# 2011-12-09 12:50:00   16.528090   401.177547
# 2011-12-09 12:50:00   22.967411   430.867483
# 2011-12-09 12:50:00   15.292640   311.334317
# 2011-12-09 12:50:00   17.833448   304.697443
# 2011-12-09 12:50:00   19.215476   389.605564

# %% [markdown]
# ### Now lets move to individual products

# %%
def get_top_products(n=5, by=None):
    return df.groupby("IDPRODUCTO")[by].sum().sort_values(ascending=False)[:n]
top_p_q = get_top_products(n=8, by="#UNIDADES") # Top products by units
top_p_r = get_top_products(n=8, by="total_price") # Top products by revenue
print("Top products by quantity", "\n", "-"*30)
print(top_p_q, "\n")
print("Top products by revenue", "\n", "-"*30)
print(top_p_r)
# df.groupby(["IDPRODUCTO", "PRODUCTO"])["#UNIDADES"].sum()
# ts = df.set_index("FECHA")[["#UNIDADES", "MARCA", "total_price"]]
print(df.columns)
# Out:
# Top products by quantity
#  ------------------------------
# IDPRODUCTO
# 85099    163177
# 84077    108545
# 85123     96664
# 21212     95450
# 84879     80705
# 22197     79363
# 17003     70700
# 21977     56575
# Name: #UNIDADES, dtype: int64
#
# Top products by revenue
#  ------------------------------
# IDPRODUCTO
# 22423    6.565473e+06
# 85099    6.243837e+06
# 85123    5.146354e+06
# 47566    3.412802e+06
# 84997    2.782167e+06
# 84879    2.621593e+06
# 22086    2.426333e+06
# 15056    2.406761e+06
# Name: total_price, dtype: float64
# Index(['FOLIO_FACTURA', 'IDPRODUCTO', 'MARCA', '#UNIDADES', 'CPRECIO',
#        'IDCLIENTE', 'YEAR', 'CTIPOCAM01', 'MES', 'COSTOPESOS', 'total_price'],
#       dtype='object')

# %%
# # df.head()
from statsmodels.tsa.stattools import adfuller
ts = df[["#UNIDADES", "IDPRODUCTO", "total_price"]]
units_ts = ts[["#UNIDADES", "IDPRODUCTO"]]
test_ts = None
for prod_id in top_p_q.index[:1]:  # Extract only the product ID
    product = prod_id
    d_range_s = "2009-12"
    d_range_e = "2011-12"
    resample = "W"
    new_ts = units_ts[units_ts["IDPRODUCTO"] == prod_id]["#UNIDADES"]
    plt.figure()
    new_ts2 = new_ts[d_range_s:d_range_e].resample(resample).max()
    new_ts2.plot(label=product, figsize=(12, 3))
    plt.legend()
    plt.figure()
    new_ts3 = new_ts[d_range_s:d_range_e].resample(resample).mean()
    new_ts3.plot(label=product, figsize=(12, 3))
    test_ts = np.log(new_ts3)
    plt.legend()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
from statsmodels.tsa.stattools import adfuller
def plot_acf_pacf(your_data, lags):
   fig = plt.figure(figsize=(12,8))
   ax1 = fig.add_subplot(211)
   fig = plot_acf(your_data, lags=lags, ax=ax1)
   ax2 = fig.add_subplot(212)
   fig = plot_pacf(your_data, lags=lags, ax=ax2)
   plt.show()
def test_stationarity(timeseries):

    #Determing rolling statistics
    rolmean = timeseries.rolling(window=12, center=False).mean()
    rolstd = timeseries.rolling(window=12, center=False).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(test_ts.fillna(1))
plot_acf_pacf(test_ts.fillna(0), 40)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.862102e+00
# p-value                        4.206561e-17
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.050000e+02
# Critical Value (1%)           -3.494220e+00
# Critical Value (5%)           -2.889485e+00
# Critical Value (10%)          -2.581676e+00
# dtype: float64

# %%
first_difference = test_ts - test_ts.shift(1)
test_stationarity(first_difference.fillna(1))
plot_acf_pacf(first_difference.fillna(1), 40)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.894833e+00
# p-value                        3.480174e-17
# #Lags Used                     2.000000e+00
# Number of Observations Used    1.030000e+02
# Critical Value (1%)           -3.495493e+00
# Critical Value (5%)           -2.890037e+00
# Critical Value (10%)          -2.581971e+00
# dtype: float64

# %%
seasonal_difference = first_difference - test_ts.shift(11)
test_stationarity(seasonal_difference.fillna(1))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.893819e+00
# p-value                        2.882644e-07
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.050000e+02
# Critical Value (1%)           -3.494220e+00
# Critical Value (5%)           -2.889485e+00
# Critical Value (10%)          -2.581676e+00
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf_pacf(seasonal_difference.fillna(0), 40)
# seasonal_difference.plot()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Read and process data
df2 = read_test_data("/kaggle/input/series-data/BASEVENTAS2010A2015.csv")
df2["FECHA"] = pd.to_datetime(df2["FECHA"], errors="coerce")
test_ts = test_ts.dropna()

# Prepare time series data
ts2 = df2.set_index("FECHA")["#UNIDADES"]
ts2 = np.log(ts2.sort_index())
ts2[ts2 == -inf] = 0
ts2 = pd.DataFrame(ts2.resample("W").mean())

df2 = pd.DataFrame(test_ts.fillna(0))
new_df = pd.concat([df2, ts2.fillna(1)])

# Fit SARIMAX models
model1 = SARIMAX(test_ts, order=(2,1,0), trend='n', time_varying_regression=True, mle_regression=False, seasonal_order=(1,1,1,11)).fit()
model2 = SARIMAX(test_ts, order=(0,1,2), trend='n', time_varying_regression=True, mle_regression=False, seasonal_order=(1,1,1,11)).fit()

# Generate future dates
future_dates = pd.date_range(start=test_ts.index[-1] + pd.Timedelta(weeks=1), periods=20, freq="W")

# Create DataFrame for predictions
forecast_df = pd.DataFrame(index=future_dates)
forecast_df["model1"] = model1.forecast(steps=20).values
forecast_df["model2"] = model2.forecast(steps=20).values

# Concatenate with test data
new_df = pd.concat([test_ts.to_frame(name="#UNIDADES"), forecast_df])

# Convert back from log scale
new_df = np.exp(new_df)

# Plot results
plt.figure(figsize=(18, 8))
plt.plot(new_df.index, new_df["model1"], label="Model 1 Prediction", linestyle="dashed")
plt.plot(new_df.index, new_df["model2"], label="Model 2 Prediction", linestyle="dashed")
plt.plot(new_df.index, new_df["#UNIDADES"], label="Actual Data", color="black")
plt.legend()
plt.show()
# Out:
# <ipython-input-103-d89bd9cdfcd3>:15: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df = pd.read_csv(path, infer_datetime_format=True,dtype=str)
# <ipython-input-103-d89bd9cdfcd3>:17: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %% [markdown]
# ### Calculate metrics of my model

# %%
y_true = new_df[~new_df["model1"].isnull()]["#UNIDADES"]
y_pred_1 = new_df[~new_df["model1"].isnull()]["model1"]
y_pred_2 = new_df[~new_df["model1"].isnull()]["model2"]

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                            #UNIDADES   No. Observations:                  103
# Model:             SARIMAX(2, 1, 0)x(1, 1, [1], 11)   Log Likelihood                 -63.418
# Date:                              Sat, 08 Feb 2025   AIC                            136.837
# Time:                                      18:07:19   BIC                            149.391
# Sample:                                           0   HQIC                           141.902
#                                               - 103
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7480      0.117     -6.406      0.000      -0.977      -0.519
# ar.L2         -0.3736      0.121     -3.085      0.002      -0.611      -0.136
# ar.S.L11       0.1131      0.186      0.608      0.544      -0.252       0.478
# ma.S.L11      -0.9946      6.092     -0.163      0.870     -12.935      10.946
# sigma2         0.1844      1.109      0.166      0.868      -1.990       2.359
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.71   Jarque-Bera (JB):                 2.89
# Prob(Q):                              0.40   Prob(JB):                         0.24
# Heteroskedasticity (H):               1.27   Skew:                             0.42
# Prob(H) (two-sided):                  0.51   Kurtosis:                         2.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                            #UNIDADES   No. Observations:                  103
# Model:             SARIMAX(2, 1, 0)x(1, 1, [1], 11)   Log Likelihood                 -63.418
# Date:                              Sat, 08 Feb 2025   AIC                            136.837
# Time:                                      18:08:17   BIC                            149.391
# Sample:                                           0   HQIC                           141.902
#                                               - 103
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7480      0.117     -6.406      0.000      -0.977      -0.519
# ar.L2         -0.3736      0.121     -3.085      0.002      -0.611      -0.136
# ar.S.L11       0.1131      0.186      0.608      0.544      -0.252       0.478
# ma.S.L11      -0.9946      6.092     -0.163      0.870     -12.935      10.946
# sigma2         0.1844      1.109      0.166      0.868      -1.990       2.359
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.71   Jarque-Bera (JB):                 2.89
# Prob(Q):                              0.40   Prob(JB):                         0.24
# Heteroskedasticity (H):               1.27   Skew:                             0.42
# Prob(H) (two-sided):                  0.51   Kurtosis:                         2.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
